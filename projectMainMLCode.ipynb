# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
import math
import os
import warnings
warnings.filterwarnings('ignore')

from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import classification_report, confusion_matrix

import keras
from tensorflow import keras
from keras import Sequential
from keras import layers
import tensorflow as tf
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dense, Dropout, Activation, BatchNormalization, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

plt.rcParams["figure.figsize"] = (10,6)
plt.rcParams['figure.dpi'] = 300
colors = ["#B6EE56", "#D85F9C", "#EEA756", "#56EEE8"]

# %%
#   Paths

PATH = "C:/Users/Harpyi/Desktop/Alzheimer-Project/AlzPro/Dataset"
checkpoint_filepath = "C:/Users/Harpyi/Desktop/Alzheimer-Project/AlzPro/MLCodes"
manuelTestPath = "C:/Users/Harpyi/Desktop/Alzheimer-Project/AlzPro/manuelTestImages/moderAlz.png"
modelSavePath = "C:/Users/Harpyi/Desktop/Alzheimer-Project/AlzPro/Models/v2" #you can change version of this path like v3

# %%
class_dist = {}
def image_counter(folder_path):
    basename = os.path.basename(folder_path)
    print('\033[92m'+f"A search has been initiated within the folder named '{basename}'."+'\033[0m')
    image_extensions = ['.jpg', '.jpeg', '.png']

    for root, dirs, _ in os.walk(folder_path):
        for dir_name in dirs:
            dir_path = os.path.join(root, dir_name)
            count = 0

            for filename in os.listdir(dir_path):
                file_ext = os.path.splitext(filename)[1].lower()

                if file_ext in image_extensions:
                    count += 1
            
            class_dist[dir_name] = count
            print(f"There are \033[35m{count}\033[0m images in the {dir_name} folder.")
    print('\033[92m'+"The search has been completed."+'\033[0m')
    
    keys = list(class_dist.keys())
    values = list(class_dist.values())
    explode = (0.1,)*len(keys)
    
    labels = [f'{key} ({value} images)' for key, value in zip(keys, values)]
    
    plt.pie(values, explode=explode,labels=labels, autopct='%1.1f%%',
            shadow=False, startangle=90, colors=colors, textprops={'fontsize': 12, "fontweight" : "bold", "color":"darkblue"},  wedgeprops=
           {'edgecolor':'darkblue'} , labeldistance=1.15)
    plt.title("Distribution of \nAlzheimer MRI Images", size=12, fontweight="bold")

image_counter(PATH)
# Out:
# A search has been initiated within the folder named 'Dataset'.
# There are 896 images in the Mild_Demented folder.
# There are 64 images in the Moderate_Demented folder.
# There are 3200 images in the Non_Demented folder.
# There are 2240 images in the Very_Mild_Demented folder.
# The search has been completed.

# %%
data = tf.keras.utils.image_dataset_from_directory(PATH,
                                                batch_size = 32,
                                                image_size=(128, 128),
                                                shuffle=True,
                                                seed=42,)

class_names = data.class_names
# Out:
# Found 6400 files belonging to 4 classes.

# %%
def sample_bringer(path, target, num_samples=5):
    
    class_path = os.path.join(path, target)

    image_files = [image for image in os.listdir(class_path) if image.endswith('.jpg')]

    fig, ax = plt.subplots(1, num_samples, facecolor="gray")
    fig.suptitle(f'{target} Brain MRI Samples', color="yellow",fontsize=16, fontweight='bold', y=0.75)
    
    for i in range(num_samples):
        image_path = os.path.join(class_path, image_files[i])
        img = mpimg.imread(image_path)

        ax[i].imshow(img)
        ax[i].axis('off')
        ax[i].set_title(f'Sample {i+1}', color="aqua")

    plt.tight_layout()
    
for target in class_names:
    sample_bringer(PATH, target=target)

# %%
alz_dict = {index: img for index, img in enumerate(data.class_names)}

class Process:
    def __init__(self, data):
        self.data = data.map(lambda x, y: (x/255, y))

    def create_new_batch(self):
        self.batch = self.data.as_numpy_iterator().next()
        text = "Min and max pixel values in the batch ->"
        print(text, self.batch[0].min(), "&", self.batch[0].max())
        
    def show_batch_images(self, number_of_images=5):
        fig, ax = plt.subplots(ncols=number_of_images, figsize=(20,20), facecolor="gray")
        fig.suptitle("Brain MRI (Alzheimer) Samples in the Batch", color="yellow",fontsize=18, fontweight='bold', y=0.6)
        for idx, img in enumerate(self.batch[0][:number_of_images]):
            ax[idx].imshow(img)
            class_no = self.batch[1][idx]
            ax[idx].set_title(alz_dict[class_no], color="aqua")
            ax[idx].set_xticklabels([])
            ax[idx].set_yticklabels([])
    
    def train_test_val_split(self, train_size, val_size, test_size):

        train = int(len(self.data)*train_size)
        test = int(len(self.data)*test_size)
        val = int(len(self.data)*val_size)
        
        train_data = self.data.take(train)
        val_data = self.data.skip(train).take(val)
        test_data = self.data.skip(train+val).take(test)

        return train_data, val_data, test_data

# %%
process = Process(data)
process.create_new_batch()
process.show_batch_images(number_of_images=5)
# Out:
# Min and max pixel values in the batch -> 0.0 & 1.0

# %%
train_data, val_data, test_data= process.train_test_val_split(train_size=0.8, val_size=0.1, test_size=0.1)

# %%
y_train = tf.concat(list(map(lambda x: x[1], train_data)), axis=0)
class_weight = compute_class_weight('balanced',classes=np.unique(y_train), y=y_train.numpy())
class_weights = dict(zip(np.unique(y_train), class_weight))

# %%
def build_model():
    model = Sequential()
    
    model.add(Conv2D(filters=16, kernel_size=(3, 3), strides=(1, 1), activation="relu", kernel_initializer='he_normal',
                     input_shape=(128, 128, 3)))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(filters=32, kernel_size=(3, 3), strides=(1, 1), activation="relu", kernel_initializer='he_normal'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    
    model.add(Conv2D(filters=128, kernel_size=(3, 3), strides=(1, 1), activation="relu", kernel_initializer='he_normal'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    
    model.add(Flatten())
    model.add(Dense(128, activation="relu", kernel_initializer='he_normal'))
    model.add(Dense(64, activation="relu"))
    model.add(Dense(4, activation="softmax"))

    model.compile(optimizer='adam', loss="sparse_categorical_crossentropy", metrics=['accuracy'])
    
    model.summary()
    
    return model

model = build_model()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 126, 126, 16)      448
#
#  max_pooling2d_3 (MaxPooling  (None, 63, 63, 16)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 61, 61, 32)        4640
#
#  max_pooling2d_4 (MaxPooling  (None, 30, 30, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 28, 28, 128)       36992
#
#  max_pooling2d_5 (MaxPooling  (None, 14, 14, 128)      0
#  2D)
#
#  flatten_1 (Flatten)         (None, 25088)             0
#
#  dense_3 (Dense)             (None, 128)               3211392
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  dense_5 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 3,261,988
# Trainable params: 3,261,988
# Non-trainable params: 0
# _________________________________________________________________

# %%
def checkpoint_callback():
    
    model_checkpoint_callback= ModelCheckpoint(filepath=checkpoint_filepath,
                           save_weights_only=False,
                           frequency='epoch',
                           monitor='val_accuracy',
                           save_best_only=True,
                           verbose=1)
    
    return model_checkpoint_callback

def early_stopping(patience):
    es_callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=patience, verbose=1)
    return es_callback


EPOCHS = 20
checkpoint_callback = checkpoint_callback()
early_stopping = early_stopping(patience=5)
callbacks = [checkpoint_callback, early_stopping]

# %%
history = model.fit(train_data, epochs = EPOCHS, validation_data = val_data, class_weight = class_weights, callbacks = callbacks)
# Out:
# Epoch 1/20
# 160/160 [==============================] - ETA: 0s - loss: 1.6198 - accuracy: 0.3109
# Epoch 1: val_accuracy improved from -inf to 0.55781, saving model to C:/Users/Harpyi/Desktop/Alzheimer-Project/AlzPro\MLCodes
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:/Users/Harpyi/Desktop/Alzheimer-Project/AlzPro\MLCodes\assets
# INFO:tensorflow:Assets written to: C:/Users/Harpyi/Desktop/Alzheimer-Project/AlzPro\MLCodes\assets
# 160/160 [==============================] - 21s 128ms/step - loss: 1.6198 - accuracy: 0.3109 - val_loss: 1.1474 - val_accuracy: 0.5578
# Epoch 2/20
# 160/160 [==============================] - ETA: 0s - loss: 1.2122 - accuracy: 0.4480
# Epoch 2: val_accuracy did not improve from 0.55781
# 160/160 [==============================] - 17s 103ms/step - loss: 1.2122 - accuracy: 0.4480 - val_loss: 1.4873 - val_accuracy: 0.3219
# Epoch 3/20
# 160/160 [==============================] - ETA: 0s - loss: 0.9233 - accuracy: 0.5312
# Epoch 3: val_accuracy improved from 0.55781 to 0.63906, saving model to C:/Users/Harpyi/Desktop/Alzheimer-Project/AlzPro\MLCodes
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:/Users/Harpyi/Desktop/Alzheimer-Project/AlzPro\MLCodes\assets
# INFO:tensorflow:Assets written to: C:/Users/Harpyi/Desktop/Alzheimer-Project/AlzPro\MLCodes\assets
# 160/160 [==============================] - 17s 107ms/step - loss: 0.9233 - accuracy: 0.5312 - val_loss: 0.7945 - val_accuracy: 0.6391
# Epoch 4/20
# 160/160 [==============================] - ETA: 0s - loss: 0.5218 - accuracy: 0.6680
# Epoch 4: val_accuracy did not improve from 0.63906
# 160/160 [==============================] - 16s 100ms/step - loss: 0.5218 - accuracy: 0.6680 - val_loss: 0.9114 - val_accuracy: 0.5797
# Epoch 5/20
# 160/160 [==============================] - ETA: 0s - loss: 0.3089 - accuracy: 0.8025
# Epoch 5: val_accuracy improved from 0.63906 to 0.86563, saving model to C:/Users/Harpyi/Desktop/Alzheimer-Project/AlzPro\MLCodes
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:/Users/Harpyi/Desktop/Alzheimer-Project/AlzPro\MLCodes\assets
# INFO:tensorflow:Assets written to: C:/Users/Harpyi/Desktop/Alzheimer-Project/AlzPro\MLCodes\assets
# 160/160 [==============================] - 18s 110ms/step - loss: 0.3089 - accuracy: 0.8025 - val_loss: 0.3269 - val_accuracy: 0.8656
# Epoch 6/20
# 160/160 [==============================] - ETA: 0s - loss: 0.1271 - accuracy: 0.9285
# Epoch 6: val_accuracy improved from 0.86563 to 0.96406, saving model to C:/Users/Harpyi/Desktop/Alzheimer-Project/AlzPro\MLCodes
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:/Users/Harpyi/Desktop/Alzheimer-Project/AlzPro\MLCodes\assets
# INFO:tensorflow:Assets written to: C:/Users/Harpyi/Desktop/Alzheimer-Project/AlzPro\MLCodes\assets
# 160/160 [==============================] - 18s 112ms/step - loss: 0.1271 - accuracy: 0.9285 - val_loss: 0.1371 - val_accuracy: 0.9641
# Epoch 7/20
# 160/160 [==============================] - ETA: 0s - loss: 0.0460 - accuracy: 0.9801
# Epoch 7: val_accuracy improved from 0.96406 to 0.96875, saving model to C:/Users/Harpyi/Desktop/Alzheimer-Project/AlzPro\MLCodes
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:/Users/Harpyi/Desktop/Alzheimer-Project/AlzPro\MLCodes\assets
# INFO:tensorflow:Assets written to: C:/Users/Harpyi/Desktop/Alzheimer-Project/AlzPro\MLCodes\assets
# 160/160 [==============================] - 18s 114ms/step - loss: 0.0460 - accuracy: 0.9801 - val_loss: 0.0984 - val_accuracy: 0.9688
# Epoch 8/20
# 160/160 [==============================] - ETA: 0s - loss: 0.0290 - accuracy: 0.9900
# Epoch 8: val_accuracy did not improve from 0.96875
# 160/160 [==============================] - 17s 102ms/step - loss: 0.0290 - accuracy: 0.9900 - val_loss: 0.0785 - val_accuracy: 0.9672
# Epoch 9/20
# 160/160 [==============================] - ETA: 0s - loss: 0.0096 - accuracy: 0.9963
# Epoch 9: val_accuracy improved from 0.96875 to 0.98750, saving model to C:/Users/Harpyi/Desktop/Alzheimer-Project/AlzPro\MLCodes
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:/Users/Harpyi/Desktop/Alzheimer-Project/AlzPro\MLCodes\assets
# INFO:tensorflow:Assets written to: C:/Users/Harpyi/Desktop/Alzheimer-Project/AlzPro\MLCodes\assets
# 160/160 [==============================] - 18s 114ms/step - loss: 0.0096 - accuracy: 0.9963 - val_loss: 0.0461 - val_accuracy: 0.9875
# Epoch 10/20
# 160/160 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 1.0000
# Epoch 10: val_accuracy improved from 0.98750 to 0.99219, saving model to C:/Users/Harpyi/Desktop/Alzheimer-Project/AlzPro\MLCodes
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:/Users/Harpyi/Desktop/Alzheimer-Project/AlzPro\MLCodes\assets
# INFO:tensorflow:Assets written to: C:/Users/Harpyi/Desktop/Alzheimer-Project/AlzPro\MLCodes\assets
# 160/160 [==============================] - 20s 125ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0430 - val_accuracy: 0.9922
# Epoch 11/20
# 160/160 [==============================] - ETA: 0s - loss: 7.5006e-04 - accuracy: 1.0000
# Epoch 11: val_accuracy improved from 0.99219 to 0.99531, saving model to C:/Users/Harpyi/Desktop/Alzheimer-Project/AlzPro\MLCodes
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:/Users/Harpyi/Desktop/Alzheimer-Project/AlzPro\MLCodes\assets
# INFO:tensorflow:Assets written to: C:/Users/Harpyi/Desktop/Alzheimer-Project/AlzPro\MLCodes\assets
# 160/160 [==============================] - 19s 120ms/step - loss: 7.5006e-04 - accuracy: 1.0000 - val_loss: 0.0182 - val_accuracy: 0.9953
# Epoch 12/20
# 160/160 [==============================] - ETA: 0s - loss: 4.2971e-04 - accuracy: 1.0000
# Epoch 12: val_accuracy did not improve from 0.99531
# 160/160 [==============================] - 20s 125ms/step - loss: 4.2971e-04 - accuracy: 1.0000 - val_loss: 0.0155 - val_accuracy: 0.9953
# Epoch 13/20
# 160/160 [==============================] - ETA: 0s - loss: 3.0523e-04 - accuracy: 1.0000
# Epoch 13: val_accuracy did not improve from 0.99531
# 160/160 [==============================] - 17s 107ms/step - loss: 3.0523e-04 - accuracy: 1.0000 - val_loss: 0.0243 - val_accuracy: 0.9937
# Epoch 14/20
# 160/160 [==============================] - ETA: 0s - loss: 2.3330e-04 - accuracy: 1.0000
# Epoch 14: val_accuracy did not improve from 0.99531
# 160/160 [==============================] - 18s 110ms/step - loss: 2.3330e-04 - accuracy: 1.0000 - val_loss: 0.0138 - val_accuracy: 0.9953
# Epoch 15/20
# 160/160 [==============================] - ETA: 0s - loss: 1.8728e-04 - accuracy: 1.0000
# Epoch 15: val_accuracy did not improve from 0.99531
# 160/160 [==============================] - 16s 102ms/step - loss: 1.8728e-04 - accuracy: 1.0000 - val_loss: 0.0234 - val_accuracy: 0.9937
# Epoch 16/20
# 160/160 [==============================] - ETA: 0s - loss: 1.5498e-04 - accuracy: 1.0000
# Epoch 16: val_accuracy did not improve from 0.99531
# 160/160 [==============================] - 15s 94ms/step - loss: 1.5498e-04 - accuracy: 1.0000 - val_loss: 0.0203 - val_accuracy: 0.9953
# Epoch 17/20
# 160/160 [==============================] - ETA: 0s - loss: 1.2927e-04 - accuracy: 1.0000
# Epoch 17: val_accuracy improved from 0.99531 to 0.99687, saving model to C:/Users/Harpyi/Desktop/Alzheimer-Project/AlzPro\MLCodes
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:/Users/Harpyi/Desktop/Alzheimer-Project/AlzPro\MLCodes\assets
# INFO:tensorflow:Assets written to: C:/Users/Harpyi/Desktop/Alzheimer-Project/AlzPro\MLCodes\assets
# 160/160 [==============================] - 17s 107ms/step - loss: 1.2927e-04 - accuracy: 1.0000 - val_loss: 0.0083 - val_accuracy: 0.9969
# Epoch 18/20
# 160/160 [==============================] - ETA: 0s - loss: 1.0731e-04 - accuracy: 1.0000
# Epoch 18: val_accuracy did not improve from 0.99687
# 160/160 [==============================] - 17s 108ms/step - loss: 1.0731e-04 - accuracy: 1.0000 - val_loss: 0.0171 - val_accuracy: 0.9953
# Epoch 19/20
# 160/160 [==============================] - ETA: 0s - loss: 8.8635e-05 - accuracy: 1.0000
# Epoch 19: val_accuracy did not improve from 0.99687
# 160/160 [==============================] - 16s 99ms/step - loss: 8.8635e-05 - accuracy: 1.0000 - val_loss: 0.0262 - val_accuracy: 0.9953
# Epoch 20/20
# 160/160 [==============================] - ETA: 0s - loss: 7.6645e-05 - accuracy: 1.0000
# Epoch 20: val_accuracy did not improve from 0.99687
# 160/160 [==============================] - 15s 93ms/step - loss: 7.6645e-05 - accuracy: 1.0000 - val_loss: 0.0322 - val_accuracy: 0.9953

# %%
fig, ax = plt.subplots(1, 2, figsize=(12,6), facecolor="khaki")
ax[0].set_facecolor('palegoldenrod')  
ax[0].set_title('Loss', fontweight="bold")
ax[0].set_xlabel("Epoch", size=14)
ax[0].plot(history.epoch, history.history["loss"], label="Train Loss", color="navy")
ax[0].plot(history.epoch, history.history["val_loss"], label="Validation Loss", color="crimson", linestyle="dashed")
ax[0].legend()
ax[1].set_facecolor('palegoldenrod')
ax[1].set_title('Accuracy', fontweight="bold")
ax[1].set_xlabel("Epoch", size=14)
ax[1].plot(history.epoch, history.history["accuracy"], label="Train Acc.", color="navy")
ax[1].plot(history.epoch, history.history["val_accuracy"], label="Validation Acc.", color="crimson", linestyle="dashed")
ax[1].legend()

# %%
model.evaluate(test_data)
# Out:
# 20/20 [==============================] - 2s 33ms/step - loss: 0.0535 - accuracy: 0.9922
# [0.0535493902862072, 0.9921875]

# %%
predictions = []
labels = []

for X, y in test_data.as_numpy_iterator():
    y_pred = model.predict(X, verbose=0)
    y_prediction = np.argmax(y_pred, axis=1)
    predictions.extend(y_prediction)
    labels.extend(y)
    
predictions = np.array(predictions)
labels = np.array(labels)

print(classification_report(labels, predictions, target_names=class_names))
# Out:
#                     precision    recall  f1-score   support
#
#      Mild_Demented       1.00      0.96      0.98        75
#  Moderate_Demented       1.00      1.00      1.00         5
#       Non_Demented       0.99      1.00      1.00       327
# Very_Mild_Demented       0.99      1.00      0.99       233
#
#           accuracy                           0.99       640
#          macro avg       1.00      0.99      0.99       640
#       weighted avg       0.99      0.99      0.99       640

# %%
cm = confusion_matrix(labels, predictions)
cm_df = pd.DataFrame(cm, index=class_names, columns=class_names)
cm_df
plt.figure(figsize=(10,6), dpi=300)
sns.heatmap(cm_df, annot=True, cmap="Greys", fmt=".1f")
plt.title("Confusion Matrix", fontweight="bold")
plt.xlabel("Predicted", fontweight="bold")
plt.ylabel("True", fontweight="bold")
# Out:
# Text(286.1666666666666, 0.5, 'True')

# %%
def random_mri_prob_bringer(image_number=0):
    
    for images, _ in test_data.skip(5).take(1):
        image = images[image_number]
        pred = model.predict(tf.expand_dims(image, 0))[0]
        
    probs = list(tf.nn.softmax(pred).numpy()) 
    probs_dict = dict(zip(class_dist.keys(), probs))
    
    keys = list(probs_dict.keys())
    values = list(probs_dict.values())

    fig, (ax1, ax2) = plt.subplots(1, 2, facecolor='black')
    plt.subplots_adjust(wspace=0.4) 
    ax1.imshow(image)
    ax1.set_title('Brain MRI', color="yellow", fontweight="bold", fontsize=16)
    
    edges = ['left', 'bottom', 'right', 'top']
    edge_color = "greenyellow"
    edge_width = 3
    for edge in edges:
        ax1.spines[edge].set_linewidth(edge_width)
        ax1.spines[edge].set_edgecolor(edge_color)

    plt.gca().axes.yaxis.set_ticklabels([])        
    plt.gca().axes.xaxis.set_ticklabels([])

    wedges, labels, autopct = ax2.pie(values, labels=keys,  autopct='%1.1f%%',
        shadow=True, startangle=90, colors=colors, textprops={'fontsize': 8, "fontweight":"bold", "color":"white"},  wedgeprops=
       {'edgecolor':'black'} , labeldistance=1.15)

    for autotext in autopct:
        autotext.set_color('black')

    ax2.set_title('Alzheimer Probabilities', color="yellow", fontweight="bold", fontsize=16)
    
rand_img_no = np.random.randint(1, 32)
random_mri_prob_bringer(image_number=rand_img_no)
# Out:
# 1/1 [==============================] - 0s 76ms/step

# %%
plt.figure(figsize=(20, 20), facecolor="gray")
for images, labels in test_data.take(1):
    for i in range(25):
        ax = plt.subplot(5, 5, i + 1)
        plt.imshow(images[i])
        predictions = model.predict(tf.expand_dims(images[i], 0), verbose=0)
        score = tf.nn.softmax(predictions[0])
        if(class_names[labels[i]]==class_names[np.argmax(score)]):
            plt.title("Actual: "+class_names[labels[i]], color="aqua", fontweight="bold", fontsize=10)
            plt.ylabel("Predicted: "+class_names[np.argmax(score)], color="springgreen", fontweight="bold", fontsize=10)
            ok_text = plt.text(2, 10, "OK \u2714", color="springgreen", fontsize=14)
            ok_text.set_bbox(dict(facecolor='lime', alpha=0.5))
    
        else:
            plt.title("Actual: "+class_names[labels[i]], color="aqua", fontweight="bold", fontsize=10)
            plt.ylabel("Predicted: "+class_names[np.argmax(score)], color="maroon", fontweight="bold", fontsize=10)
            nok_text = plt.text(2, 10, "NOK \u2718", color="red", fontsize=14)
            nok_text.set_bbox(dict(facecolor='maroon', alpha=0.5))
        plt.gca().axes.yaxis.set_ticklabels([])        
        plt.gca().axes.xaxis.set_ticklabels([])

# %%
import tensorflow as tf
import numpy as np

def singlepredict(image_path, model):
    class_names = ["mild_demanded", "moderate_demanded", "non_demanded", "very_mild_demanded"]
    
    img = tf.keras.preprocessing.image.load_img(image_path, target_size=(128, 128))
    img_array = tf.keras.preprocessing.image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array /= 255.0  

    predictions = model.predict(img_array, verbose=0)
    predicted_class = class_names[np.argmax(predictions)]

    accuracy = np.max(predictions) * 100

    print(f"Predicted Class: {predicted_class}")
    print(f"Accuracy: {accuracy:.2f}%")

# %%
singlepredict(manuelTestPath,model)
# Out:
# Predicted Class: moderate_demanded
# Accuracy: 99.85%

# %%
model.save(modelSavePath)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:/Users/Harpyi/Desktop/Alzheimer-Project/AlzPro/Models/v2\assets
# INFO:tensorflow:Assets written to: C:/Users/Harpyi/Desktop/Alzheimer-Project/AlzPro/Models/v2\assets
